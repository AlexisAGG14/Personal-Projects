# %% [markdown]
# # World Meat Production part 1
#
# ### Hello everyone and welcome to my python personal project where I analyse the world meat production and its relation with some countries around the world
# ### In part 1 we are gonna make some graphs and analyze some historical moments and its correalation with meat production

# %%
#First of all we import the libraries to use
import pandas as pd
import matplotlib as plt
import numpy as np
from ing_theme_matplotlib import mpl_style
mpl_style(dark=True)

# %%
#Showing the data about CO2 in the selected countries
CO210=pd.read_csv('CO2Countries.csv')   
DFCO210=pd.DataFrame(data=CO210)
DFCO210
Graph= DFCO210.groupby('Year').agg(China =('CO2_China','sum'), México=('CO2_Mexico','sum'),USA=('CO2_USA','sum'),
India=('CO2_India','sum'), Brazil=('CO2_Brazil','sum'),France=('CO2_France','sum'),
Rusia=('CO2_Rusia','sum'),Spain=('CO2_Spain','sum'), Vietnam=('CO2_Vienam','sum'),Canada=('CO2_Canada','sum'))
Graph.plot(kind='line',title= 'CO2 per Country', style='-o', cmap='gist_rainbow',figsize=(16,10),grid="on")
# Out:
# <AxesSubplot:title={'center':'CO2 per Country'}, xlabel='Year'>

# %% [markdown]
# ## Interest notes
# #### - Russia: CO2 has a radical decease at 1991 with the desintegration of the USSR
# #### - China: Around the years 2000´s China became the "world´s factory" that means a lot of imports and exports from the country, this means a los of new fabrics, that means a increase in the CO2 in the country, and later in 2010´s we see CO2, stoped its growing and even it started to decrease, this as reponse of the actions of the China goverment, a lot of factories moved to Bangladesh or India and China started a new age to scientific development instead of being the "world´s factory" who was used to be for decades.

# %% [markdown]
# ### We see the graph, everything is according our what we can hope
#
# ### NOTE: We dont have Data in France in 2017 and 2018, thats the reason why in the graph looks in 0

# %%
#Showing the data about Meat Production in the selected countries
MP=pd.read_csv('WMPCountries.csv')   
DFMP=pd.DataFrame(data=MP)
DFMP
Graph1= DFMP.groupby('Year').agg(China =('China','sum'), México=('Mexico','sum'),USA=('USA','sum'),
India=('India','sum'), Brazil=('Brazil','sum'),France=('Francia','sum'),
Rusia=('Rusia','sum'),Spain=('Spain','sum'), Vietnam=('Vietnam','sum'),Canada=('Canada','sum'))
Graph1.plot(kind='line',title= 'Meat Production per Country', style='-o', cmap='gist_rainbow',figsize=(16,10),grid="on")
Graph2= DFMP.groupby('Year').agg(México=('Mexico','sum'),
India=('India','sum'), Brazil=('Brazil','sum'),France=('Francia','sum'),
Rusia=('Rusia','sum'),Spain=('Spain','sum'), Vietnam=('Vietnam','sum'),Canada=('Canada','sum'))
Graph2.plot(kind='line',title= 'Meat Production per Country without China and USA', style='-*', cmap='gist_rainbow',figsize=(16,10),grid="on")
Graph3= DFMP.groupby('Year').agg(México=('Mexico','sum'),
India=('India','sum'), France=('Francia','sum'),Spain=('Spain','sum'), Vietnam=('Vietnam','sum'),Canada=('Canada','sum'))
Graph3.plot(kind='line',title= 'Meat Production per Country without China, Rusia, Brazil and USA', 
style='-o', cmap='gist_rainbow',figsize=(16,10),grid="on")
# Out:
# <AxesSubplot:title={'center':'Meat Production per Country without China, Rusia, Brazil and USA'}, xlabel='Year'>

# %% [markdown]
# ## Notes and conclusions:
#
# ### -Russia: Meat Production has a radical decease at 1991 with the desintegration of the USSR (Also the data was proceed form just Russia and not the whole nations whose formed USSR).
# ### - China, USA and Brazil are very populated countries, so is easy for us understand why the meat production is so high.
# ### - Besides India is the second most populated country in the world its meat production is very low compared to another countries, thats why in India the main religion is hinduism. Diet in Hinduism varies with its diverse traditions. Many Hindus follow a Lacto-vegetarian diet that they believe is in sync with nature, compassionate, respectful of other life forms. The growing of population and the growing of population who eats meat in their diets is making grow the Meat production in India.
#
# ## General: Meat production is a factor to analyze when we are talking about CO2 and it has some correlation, in this very simple analysis we made today we see again how CO2 in the countries is affected by not just one factor, instead no matter how we try to have just one factor in the stats, always we ending with many things to conclude the things we conclude.
#
# #### This is just a simple analysis of Data with the goal of learning more about datasets, python and a bit of our world. Thanks to read.

# %% [markdown]
# ##### Data Provided by Food and Agriculture Organization
